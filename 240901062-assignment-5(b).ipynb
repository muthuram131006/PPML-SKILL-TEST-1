# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/muthuram/Downloads/healthcare_data.csv")
print("--- Column Names and Data Types ---")
df.info()
average_age = df['Age'].mean()
print(f"\nAverage Age of Patients: {average_age:.2f}")
print("\n--- Diagnosis Distribution ---")
diagnosis_counts = df['Diagnosis'].value_counts()
print(diagnosis_counts)
diagnosis_counts.plot(kind='bar', color='salmon')
plt.title('Common Medical Conditions')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()
# Out:
# --- Column Names and Data Types ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         15 non-null     int64
#  1   Name               15 non-null     object
#  2   Age                15 non-null     int64
#  3   Gender             15 non-null     object
#  4   Diagnosis          15 non-null     object
#  5   Date_of_Admission  15 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 852.0+ bytes
#
# Average Age of Patients: 46.67
#
# --- Diagnosis Distribution ---
# Diagnosis
# Hypertension     6
# Diabetes         4
# Asthma           3
# Heart Disease    2
# Name: count, dtype: int64
